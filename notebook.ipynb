# %% [markdown]
# # Proyek Analisis Data: Nama dataset
# - Nama: Sabil Ahmad Hidayat
# - Email: sabilahmad615@gmail.com
# - Id Dicoding: sabilahmad

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Produk apa yang paling banyak dan paling sedikit terjual?
# - Bagaimana tingkat kepuasan pelanggan terhadap pelayanan transaksi?
# - Kapan terakhir pelanggan melakukan transaksi?
# - Seberapa sering seorang pelanggan melakukan pembelian dalam beberapa bulan terakhir?
# - Berapa banyak uang yang dihabiskan pelanggan dalam beberapa bulan terakhir?

# %% [markdown]
# ## Menyiapkan semua library yang dibuthkan

# %%
# !pip install unidecode

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
from unidecode import unidecode

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %% [markdown]
# Menilai dataset customers

# %%
customers_df = pd.read_csv("https://raw.githubusercontent.com/meinhere/analisis-data/main/data/customers_dataset.csv", delimiter=',')
customers_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %% [markdown]
# Menilai dataset sellers

# %%
sellers_df = pd.read_csv("https://raw.githubusercontent.com/meinhere/analisis-data/main/data/sellers_dataset.csv", delimiter=',')
sellers_df.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %% [markdown]
# Menilai dataset geolocation

# %%
geolocation_df = pd.read_csv("https://raw.githubusercontent.com/meinhere/analisis-data/main/data/geolocation_dataset.csv", delimiter=',')
geolocation_df.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %% [markdown]
# Menilai dataset products

# %%
products_df = pd.read_csv("https://raw.githubusercontent.com/meinhere/analisis-data/main/data/products_dataset.csv", delimiter=',')
products_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %% [markdown]
# Menilai dataset product category name

# %%
product_category_df = pd.read_csv("https://raw.githubusercontent.com/meinhere/analisis-data/main/data/product_category_name_translation.csv", delimiter=',')
product_category_df.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %% [markdown]
# Menilai dataset orders

# %%
orders_df = pd.read_csv("https://raw.githubusercontent.com/meinhere/analisis-data/main/data/orders_dataset.csv", delimiter=',')
orders_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %% [markdown]
# Menilai dataset order items

# %%
order_items_df = pd.read_csv("https://raw.githubusercontent.com/meinhere/analisis-data/main/data/order_items_dataset.csv", delimiter=',')
order_items_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %% [markdown]
# Menilai dataset order payments

# %%
order_payments_df = pd.read_csv("https://raw.githubusercontent.com/meinhere/analisis-data/main/data/order_payments_dataset.csv", delimiter=',')
order_payments_df.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %% [markdown]
# Menilai dataset order reviews

# %%
order_reviews_df = pd.read_csv("https://raw.githubusercontent.com/meinhere/analisis-data/main/data/order_reviews_dataset.csv", delimiter=',')
order_reviews_df.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# ...

# %% [markdown]
# ### Assessing Data

# %%
customers_df.info()
sellers_df.info()
geolocation_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   object
#  1   seller_zip_code_prefix  3095 non-null   int64
#  2   seller_city             3095 non-null   object
#  3   seller_state            3095 non-null   object
# ...

# %%
products_df.info()
product_category_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ...

# %%
orders_df.info()
order_items_df.info()
order_payments_df.info()
order_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
# ...

# %% [markdown]
# Mengecek Missing Value

# %%
customers_df.isna().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
sellers_df.isna().sum()
# Out:
# seller_id                 0
# seller_zip_code_prefix    0
# seller_city               0
# seller_state              0
# dtype: int64

# %%
geolocation_df.isna().sum()
# Out:
# geolocation_zip_code_prefix    0
# geolocation_lat                0
# geolocation_lng                0
# geolocation_city               0
# geolocation_state              0
# dtype: int64

# %%
products_df.isna().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
product_category_df.isna().sum()
# Out:
# product_category_name            0
# product_category_name_english    0
# dtype: int64

# %%
orders_df.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
order_items_df.isna().sum()
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %%
order_payments_df.isna().sum()
# Out:
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64

# %%
order_reviews_df.isna().sum()
# Out:
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       87656
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %% [markdown]
# Mengecek Duplicated Value

# %%
print(f"""
1. total duplicate customers        = {customers_df.duplicated().sum()}
2. total duplicate sellers          = {sellers_df.duplicated().sum()}
3. total duplicate geolocation      = {geolocation_df.duplicated().sum()}
4. total duplicate products         = {products_df.duplicated().sum()}
5. total duplicate product_category = {product_category_df.duplicated().sum()}
6. total duplicate orders           = {orders_df.duplicated().sum()}
7. total duplicate order_items      = {order_items_df.duplicated().sum()}
8. total duplicate order_payments   = {order_payments_df.duplicated().sum()}
9. total duplicate order_reviews    = {order_reviews_df.duplicated().sum()}
""")
# Out:
# 1. total duplicate customers        = 0
# 2. total duplicate sellers          = 0
# 3. total duplicate geolocation      = 261831
# 4. total duplicate products         = 0
# 5. total duplicate product_category = 0
# 6. total duplicate orders           = 0
# 7. total duplicate order_items      = 0
# 8. total duplicate order_payments   = 0
# 9. total duplicate order_reviews    = 0

# %% [markdown]
# Mengecek Inaccurated Value

# %%
customers_df.describe()
# Out:
#        customer_zip_code_prefix
# count              99441.000000
# mean               35137.474583
# std                29797.938996
# min                 1003.000000
# 25%                11347.000000
# 50%                24416.000000
# 75%                58900.000000
# max                99990.000000

# %%
sellers_df.describe()
# Out:
#        seller_zip_code_prefix
# count             3095.000000
# mean             32291.059451
# std              32713.453830
# min               1001.000000
# 25%               7093.500000
# 50%              14940.000000
# 75%              64552.500000
# max              99730.000000

# %%
geolocation_df.describe()
# Out:
#        geolocation_zip_code_prefix  geolocation_lat  geolocation_lng
# count                 1.000163e+06     1.000163e+06     1.000163e+06
# mean                  3.657417e+04    -2.117615e+01    -4.639054e+01
# std                   3.054934e+04     5.715866e+00     4.269748e+00
# min                   1.001000e+03    -3.660537e+01    -1.014668e+02
# 25%                   1.107500e+04    -2.360355e+01    -4.857317e+01
# 50%                   2.653000e+04    -2.291938e+01    -4.663788e+01
# 75%                   6.350400e+04    -1.997962e+01    -4.376771e+01
# max                   9.999000e+04     4.506593e+01     1.211054e+02

# %%
products_df.describe()
# Out:
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# count         32341.000000                32341.000000        32341.000000
# mean             48.476949                  771.495285            2.188986
# std              10.245741                  635.115225            1.736766
# min               5.000000                    4.000000            1.000000
# 25%              42.000000                  339.000000            1.000000
# 50%              51.000000                  595.000000            1.000000
# 75%              57.000000                  972.000000            3.000000
# max              76.000000                 3992.000000           20.000000
#
#        product_weight_g  product_length_cm  product_height_cm  \
# count      32949.000000       32949.000000       32949.000000
# mean        2276.472488          30.815078          16.937661
# std         4282.038731          16.914458          13.637554
# ...

# %%
product_category_df.describe()
# Out:
#        product_category_name product_category_name_english
# count                     71                            71
# unique                    71                            71
# top             beleza_saude                 health_beauty
# freq                       1                             1

# %%
orders_df.describe()
# Out:
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# freq                                   1                                 1
#
#        order_status order_purchase_timestamp    order_approved_at  \
# count         99441                    99441                99281
# unique            8                    98875                90733
# top       delivered      2018-04-11 10:48:14  2018-02-27 04:31:10
# freq          96478                        3                    9
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# count                         97658                         96476
# unique                        81018                         95664
# ...

# %%
order_items_df.describe()
# Out:
#        order_item_id          price  freight_value
# count  112650.000000  112650.000000  112650.000000
# mean        1.197834     120.653739      19.990320
# std         0.705124     183.633928      15.806405
# min         1.000000       0.850000       0.000000
# 25%         1.000000      39.900000      13.080000
# 50%         1.000000      74.990000      16.260000
# 75%         1.000000     134.900000      21.150000
# max        21.000000    6735.000000     409.680000

# %%
order_payments_df.describe()
# Out:
#        payment_sequential  payment_installments  payment_value
# count       103886.000000         103886.000000  103886.000000
# mean             1.092679              2.853349     154.100380
# std              0.706584              2.687051     217.494064
# min              1.000000              0.000000       0.000000
# 25%              1.000000              1.000000      56.790000
# 50%              1.000000              1.000000     100.000000
# 75%              1.000000              4.000000     171.837500
# max             29.000000             24.000000   13664.080000

# %%
order_reviews_df.describe()
# Out:
#        review_score
# count  99224.000000
# mean       4.086421
# std        1.347579
# min        1.000000
# 25%        4.000000
# 50%        5.000000
# 75%        5.000000
# max        5.000000

# %% [markdown]
# Hasil penilaian masalah

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# Menghapus duplicate data

# %%
geolocation_df.drop_duplicates(inplace=True)

print("total duplicate geolocation : ", geolocation_df.duplicated().sum())
# Out:
# total duplicate geolocation :  0

# %% [markdown]
# Mengatasi Missing Value

# %%
order_reviews_df.review_comment_title.fillna("No Title", inplace=True)
order_reviews_df.review_comment_message.fillna("No Message", inplace=True)

order_reviews_df.isna().sum()
# Out:
# review_id                  0
# order_id                   0
# review_score               0
# review_comment_title       0
# review_comment_message     0
# review_creation_date       0
# review_answer_timestamp    0
# dtype: int64

# %%
orders_df.isna().sum()

# Untuk missing value yang berada pada dataset orders dibiarkan dikarenakan tipe data yang missing values berupa datetime
# 1. jika dilakukan penghapusan dikhawatirkan akan menghapus data yang penting
# 2. dan jika pengisian secara acak akan merusak tatanan data
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
products_df.dropna(axis=0, inplace=True)

products_df.isna().sum()
# Out:
# product_id                    0
# product_category_name         0
# product_name_lenght           0
# product_description_lenght    0
# product_photos_qty            0
# product_weight_g              0
# product_length_cm             0
# product_height_cm             0
# product_width_cm              0
# dtype: int64

# %% [markdown]
# Mengubah tipe data object menjadi datetime

# %%
orders_df_col=[
    'order_purchase_timestamp',
    'order_approved_at',
    'order_delivered_carrier_date',
    'order_delivered_customer_date',
    'order_estimated_delivery_date'
]
for col in orders_df_col:
    orders_df[col]=pd.to_datetime(orders_df[col])

orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  datetime64[ns]
#  4   order_approved_at              99281 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   97658 non-null  datetime64[ns]
#  6   order_delivered_customer_date  96476 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  99441 non-null  datetime64[ns]
# dtypes: datetime64[ns](5), object(3)
# memory usage: 6.1+ MB

# %%
order_reviews_df_col=['review_creation_date','review_answer_timestamp']

for col in order_reviews_df_col:
    order_reviews_df[col]=pd.to_datetime(order_reviews_df[col])

order_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     99224 non-null  object
#  4   review_comment_message   99224 non-null  object
#  5   review_creation_date     99224 non-null  datetime64[ns]
#  6   review_answer_timestamp  99224 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(4)
# memory usage: 5.3+ MB

# %%
order_items_df['shipping_limit_date']=pd.to_datetime(order_items_df['shipping_limit_date'])

order_items_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  datetime64[ns]
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 6.0+ MB

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore Data customers_df

# %%
customers_df.describe(include="all")
# Out:
#                              customer_id                customer_unique_id  \
# count                              99441                             99441
# unique                             99441                             96096
# top     06b8999e2fba1a1fbc88172c00ba8bc7  8d50f5eadf50201ccdcedfb9e2ac8455
# freq                                   1                                17
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         customer_zip_code_prefix customer_city customer_state
# ...

# %% [markdown]
# Melihat persebaran seluruh customers berdasarkan kota

# %%
customers_df.groupby("customer_city").customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_city
# sao paulo         15540
# rio de janeiro     6882
# belo horizonte     2773
# brasilia           2131
# curitiba           1521
#                   ...
# ibiara                1
# rio espera            1
# rio dos indios        1
# rio dos cedros        1
# lagoao                1
# Name: customer_id, Length: 4119, dtype: int64

# %% [markdown]
# Melihat persebaran seluruh customers berdasarkan provinsi

# %%
customers_df.groupby("customer_state").customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_state
# SP    41746
# RJ    12852
# MG    11635
# RS     5466
# PR     5045
# SC     3637
# BA     3380
# DF     2140
# ES     2033
# GO     2020
# PE     1652
# CE     1336
# PA      975
# MT      907
# MA      747
# MS      715
# PB      536
# PI      495
# RN      485
# AL      413
# SE      350
# TO      280
# RO      253
# AM      148
# AC       81
# AP       68
# RR       46
# Name: customer_id, dtype: int64

# %% [markdown]
# ### Explore Data geolocation_df

# %%
geolocation_df.describe(include="all")
# Out:
#         geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# count                 738332.000000    738332.000000    738332.000000
# unique                          NaN              NaN              NaN
# top                             NaN              NaN              NaN
# freq                            NaN              NaN              NaN
# mean                   38316.086800       -20.998353       -46.461098
# std                    30632.496675         5.892315         4.393705
# min                     1001.000000       -36.605374      -101.466766
# 25%                    12600.000000       -23.603061       -48.867822
# 50%                    29144.000000       -22.873588       -46.647278
# 75%                    65950.000000       -19.923336       -43.836974
# max                    99990.000000        45.065933       121.105394
#
#        geolocation_city geolocation_state
# count            738332            738332
# ...

# %% [markdown]
# Masih terdapat format penamaan geolocation_city yang masih buruk
#
# > Contoh = são paulo

# %%
(geolocation_df['geolocation_city'] == 'são paulo').sum()
# Out:
# 19718

# %%
geolocation_df['geolocation_city']=geolocation_df['geolocation_city'].apply(lambda city: unidecode(city))
(geolocation_df['geolocation_city'] == 'são paulo').sum()
# Out:
# 0

# %% [markdown]
# ### Explore Data customers_df dan orders_df

# %%
customers_orders_df = pd.merge(
    left=customers_df,
    right=orders_df,
    how="right",
    left_on="customer_id",
    right_on="customer_id"
)
customers_orders_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  9ef432eb6251297304e76186b10a928d  7c396fd4830fd04220f754e42b4e5bff
# 1  b0830fb4747a6c6d20dea0b8c802d7ef  af07308b275d755c9edb36a90c618231
# 2  41ce2a54c0b03bf3443c3d931a367089  3a653a41f6f9fc3d2a113cf8398680e8
# 3  f88197465ea7920adcdbec7375364d82  7c142cf63193a1473d2e66489a9ae977
# 4  8ab97904e6daea8866dbdbc4fb7aad2c  72632f0f9dd73dfee390c9b22eb56dd6
#
#    customer_zip_code_prefix            customer_city customer_state  \
# 0                      3149                sao paulo             SP
# 1                     47813                barreiras             BA
# 2                     75265               vianopolis             GO
# 3                     59296  sao goncalo do amarante             RN
# 4                      9195              santo andre             SP
#
#                            order_id order_status order_purchase_timestamp  \
# ...

# %% [markdown]
# ### Explore Data products_df dan product_category_df

# %%
products_with_category_df = pd.merge(
    left=products_df,
    right=product_category_df,
    how="left",
    left_on="product_category_name",
    right_on="product_category_name"
)
products_with_category_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm  \
# 0             225.0               16.0               10.0              14.0
# ...

# %% [markdown]
# ### Explore Data sellers_df dan order_items_df

# %%
order_items_with_sellers_df = pd.merge(
    left=order_items_df,
    right=sellers_df,
    how="left",
    left_on="seller_id",
    right_on="seller_id"
)
order_items_with_sellers_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value  seller_zip_code_prefix  \
# 0 2017-09-19 09:45:35   58.90          13.29                   27277
# 1 2017-05-03 11:05:13  239.90          19.93                    3471
# ...

# %% [markdown]
# ### Merged All Data

# %%
data1 = pd.merge(
    left=customers_orders_df,
    right=order_items_with_sellers_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
data1.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  9ef432eb6251297304e76186b10a928d  7c396fd4830fd04220f754e42b4e5bff
# 1  b0830fb4747a6c6d20dea0b8c802d7ef  af07308b275d755c9edb36a90c618231
# 2  41ce2a54c0b03bf3443c3d931a367089  3a653a41f6f9fc3d2a113cf8398680e8
# 3  f88197465ea7920adcdbec7375364d82  7c142cf63193a1473d2e66489a9ae977
# 4  8ab97904e6daea8866dbdbc4fb7aad2c  72632f0f9dd73dfee390c9b22eb56dd6
#
#    customer_zip_code_prefix            customer_city customer_state  \
# 0                      3149                sao paulo             SP
# 1                     47813                barreiras             BA
# 2                     75265               vianopolis             GO
# 3                     59296  sao goncalo do amarante             RN
# 4                      9195              santo andre             SP
#
#                            order_id order_status order_purchase_timestamp  \
# ...

# %%
data2 = pd.merge(
    left=data1,
    right=products_with_category_df,
    how="left",
    left_on="product_id",
    right_on="product_id"
)
data2.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  9ef432eb6251297304e76186b10a928d  7c396fd4830fd04220f754e42b4e5bff
# 1  b0830fb4747a6c6d20dea0b8c802d7ef  af07308b275d755c9edb36a90c618231
# 2  41ce2a54c0b03bf3443c3d931a367089  3a653a41f6f9fc3d2a113cf8398680e8
# 3  f88197465ea7920adcdbec7375364d82  7c142cf63193a1473d2e66489a9ae977
# 4  8ab97904e6daea8866dbdbc4fb7aad2c  72632f0f9dd73dfee390c9b22eb56dd6
#
#    customer_zip_code_prefix            customer_city customer_state  \
# 0                      3149                sao paulo             SP
# 1                     47813                barreiras             BA
# 2                     75265               vianopolis             GO
# 3                     59296  sao goncalo do amarante             RN
# 4                      9195              santo andre             SP
#
#                            order_id order_status order_purchase_timestamp  \
# ...

# %%
data3 = pd.merge(
    left=data2,
    right=order_payments_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
data3.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  9ef432eb6251297304e76186b10a928d  7c396fd4830fd04220f754e42b4e5bff
# 1  9ef432eb6251297304e76186b10a928d  7c396fd4830fd04220f754e42b4e5bff
# 2  9ef432eb6251297304e76186b10a928d  7c396fd4830fd04220f754e42b4e5bff
# 3  b0830fb4747a6c6d20dea0b8c802d7ef  af07308b275d755c9edb36a90c618231
# 4  41ce2a54c0b03bf3443c3d931a367089  3a653a41f6f9fc3d2a113cf8398680e8
#
#    customer_zip_code_prefix customer_city customer_state  \
# 0                      3149     sao paulo             SP
# 1                      3149     sao paulo             SP
# 2                      3149     sao paulo             SP
# 3                     47813     barreiras             BA
# 4                     75265    vianopolis             GO
#
#                            order_id order_status order_purchase_timestamp  \
# 0  e481f51cbdc54678b7cc49136f2d6af7    delivered      2017-10-02 10:56:33
# ...

# %%
main_data_df = pd.merge(
    left=data3,
    right=order_reviews_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
main_data_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  9ef432eb6251297304e76186b10a928d  7c396fd4830fd04220f754e42b4e5bff
# 1  9ef432eb6251297304e76186b10a928d  7c396fd4830fd04220f754e42b4e5bff
# 2  9ef432eb6251297304e76186b10a928d  7c396fd4830fd04220f754e42b4e5bff
# 3  b0830fb4747a6c6d20dea0b8c802d7ef  af07308b275d755c9edb36a90c618231
# 4  41ce2a54c0b03bf3443c3d931a367089  3a653a41f6f9fc3d2a113cf8398680e8
#
#    customer_zip_code_prefix customer_city customer_state  \
# 0                      3149     sao paulo             SP
# 1                      3149     sao paulo             SP
# 2                      3149     sao paulo             SP
# 3                     47813     barreiras             BA
# 4                     75265    vianopolis             GO
#
#                            order_id order_status order_purchase_timestamp  \
# 0  e481f51cbdc54678b7cc49136f2d6af7    delivered      2017-10-02 10:56:33
# ...

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1:

# %%
products_count = main_data_df.groupby("product_category_name_english").product_id.count().reset_index()
sum_products = products_count.sort_values(by="product_id", ascending=False)

sum_products
# Out:
#    product_category_name_english  product_id
# 7                 bed_bath_table       11988
# 43                 health_beauty       10032
# 65                sports_leisure        9004
# 39               furniture_decor        8832
# 15         computers_accessories        8150
# ..                           ...         ...
# 3          arts_and_craftmanship          24
# 52                    la_cuisine          16
# 11             cds_dvds_musicals          14
# 29     fashion_childrens_clothes           8
# 61         security_and_services           2
#
# [71 rows x 2 columns]

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(24, 6))

colors = ["#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"]

sns.barplot(x="product_id", y="product_category_name_english", data=sum_products.head(5), palette=colors, ax=ax[0])
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title("Products with the highest sales", loc="center", fontsize=18)
ax[0].tick_params(axis ='y', labelsize=15)

sns.barplot(x="product_id", y="product_category_name_english", data=sum_products.sort_values(by="product_id", ascending=True).head(5), palette=colors, ax=ax[1])
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].invert_xaxis()
ax[1].yaxis.set_label_position("right")
ax[1].yaxis.tick_right()
ax[1].set_title("Products with the lowest sales", loc="center", fontsize=18)
ax[1].tick_params(axis='y', labelsize=15)

plt.suptitle("Most and Least Sold Products", fontsize=20)
plt.show()

# %% [markdown]
# ### Pertanyaan 2:

# %%
rating_count = main_data_df["review_score"].value_counts()
rating_count
# Out:
# 5.0    66343
# 4.0    22319
# 1.0    15428
# 3.0     9894
# 2.0     4162
# Name: review_score, dtype: int64

# %%
rating_count.index
# Out:
# Float64Index([5.0, 4.0, 1.0, 3.0, 2.0], dtype='float64')

# %%
rating_count.values
# Out:
# array([66343, 22319, 15428,  9894,  4162])

# %%
colors = ["#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"]

plt.figure(figsize=(10, 5))
sns.barplot(x=rating_count.index,
            y=rating_count.values,
            order=rating_count.index,
            palette=colors)
plt.title("Rating Customers for Each Order", fontsize=15)
plt.xlabel("Rating")
plt.ylabel("Customer")
plt.xticks(fontsize=12)
plt.show()

# %% [markdown]
# ### Pertanyaan 3 - 5 (RFM):

# %%
rfm_df = main_data_df.groupby(by="customer_id", as_index=False).agg({
    "order_purchase_timestamp": "max", # mengambil tanggal order terakhir
    "order_id": "nunique", # menghitung jumlah order
    "payment_value": "sum" # menghitung jumlah revenue yang dihasilkan
})
rfm_df.columns = ["customer_id", "max_order_timestamp", "frequency", "monetary"]

# menghitung kapan terakhir pelanggan melakukan transaksi (hari)
rfm_df["max_order_timestamp"] = rfm_df["max_order_timestamp"].dt.date
recent_date = orders_df["order_purchase_timestamp"].dt.date.max()
rfm_df["recency"] = rfm_df["max_order_timestamp"].apply(lambda x: (recent_date - x).days)

rfm_df.drop("max_order_timestamp", axis=1, inplace=True)
rfm_df.head()
# Out:
#                         customer_id  frequency  monetary  recency
# 0  00012a2ce6f8dcda20d059ce98491703          1    114.74      337
# 1  000161a058600d5901f007fab4c27140          1     67.41      458
# 2  0001fd6190edaaf884bcaf3d49edf079          1    195.42      596
# 3  0002414f95344307404f0ace7a26f1d5          1    179.35      427
# 4  000379cdec625522490c315e70c7a9fb          1    107.01      198

# %%
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(30, 6))

colors = ["#72BCD4", "#72BCD4", "#72BCD4", "#72BCD4", "#72BCD4"]

sns.barplot(y="recency", x="customer_id", data=rfm_df.sort_values(by="recency", ascending=True).head(5), palette=colors, ax=ax[0])
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title("By Recency (days)", loc="center", fontsize=18)
ax[0].tick_params(axis ='x', labelsize=15)

sns.barplot(y="frequency", x="customer_id", data=rfm_df.sort_values(by="frequency", ascending=False).head(5), palette=colors, ax=ax[1])
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].set_title("By Frequency", loc="center", fontsize=18)
ax[1].tick_params(axis='x', labelsize=15)

sns.barplot(y="monetary", x="customer_id", data=rfm_df.sort_values(by="monetary", ascending=False).head(5), palette=colors, ax=ax[2])
ax[2].set_ylabel(None)
ax[2].set_xlabel(None)
ax[2].set_title("By Monetary", loc="center", fontsize=18)
ax[2].tick_params(axis='x', labelsize=15)

plt.suptitle("Best Customer Based on RFM Parameters (customer_id)", fontsize=20)
plt.show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Produk apa yang paling banyak dan paling sedikit terjual?
# - Bagaimana tingkat kepuasan pelanggan terhadap pelayanan transaksi?

# %% [markdown]
# **1. Produk apa yang paling banyak dan paling sedikit terjual?**
#
# > Berdasarkan data yang sudah divisualisasikan diatas, pembelian produk terbesar ada pada **beth_bad_table** sebanyak **11988** barang dan pembelian produk terkecil pada **security_and_service** sebanyak **2** barang.

# %% [markdown]
# **2. Bagaimana tingkat kepuasan pelanggan terhadap pelayanan transaksi??**
#
# > Sebagian besar customer memiliki tingkat kepuasan yang **sangat bagus**. Berdasarkan data yang diatas banyak customer yang memilih nilai rating 5.
#
# *Nilai Rating :*
# 5 = Sangat Bagus,
# 4 = Bagus,
# 3 = Biasa,
# 2 = Kurang,
# 1 = Sangat Kurang

# %%
main_data_df.to_csv("main_data.csv", index=False)
